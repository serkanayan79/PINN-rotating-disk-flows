# %%
import os
# DDE_BACKEND
os.environ["DDE_BACKEND"] = "pytorch"

import numpy as np
import torch
import torch_directml
import deepxde as dde
from scipy.integrate import solve_bvp
import matplotlib.pyplot as plt
import csv


# =========================================
# 1) von Kármán numerical solver (Smooth disk)
# =========================================

def vkd_ode(eta, y):
    """
    MW benzerlik ODE sistemi:
      y[0] = F,  y[1] = F',  y[2] = G,  y[3] = G',  y[4] = H
    """
    f, fp, g, gp, h = y
    return np.vstack([
        fp,
        fp * h + f**2 - g**2,
        gp,
        gp * h + 2 * f * g,
        -2 * f,
    ])


def make_vkd_bc(s_suction=0.0):
    """
    Smooth disk (no-slip) için MW sınır şartları (η uzayında):

      F(0) = 0
      G(0) = 1
      H(0) = -2 s   (s=0 -> H(0)=0)
      F(∞) = 0      (∞ ~ eta_max)
      G(∞) = 0
    """
    def vkd_bc(ya, yb):
        f0, fp0, g0, gp0, h0 = ya
        fL, fpL, gL, gpL, hL = yb
        return np.array([
            f0,                    # F(0)=0
            g0 - 1.0,              # G(0)=1
            h0 + 2.0 * s_suction,  # H(0)=-2s
            fL,                    # F(eta_max)=0
            gL,                    # G(eta_max)=0
        ])
    return vkd_bc


def solve_vkd(s_suction=0.0, eta_max=10.0, n_eta=800,
              tol=1e-8, max_nodes=200000):
    """
    Smooth disk VKD çözümü: eta ∈ [0, eta_max]
    """
    eta_mesh = np.linspace(0.0, eta_max, n_eta)

    y_guess = np.zeros((5, eta_mesh.size))
    y_guess[2, :] = 1.0                 # G ~ 1 near wall
    y_guess[4, :] = -2.0 * s_suction    # H(0) ~ -2s

    bc = make_vkd_bc(s_suction=s_suction)

    sol = solve_bvp(vkd_ode, bc, eta_mesh, y_guess,
                    tol=tol, max_nodes=max_nodes, verbose=0)

    if not sol.success:
        raise RuntimeError(
            f"VKD BVP solver did not converge for eta_max={eta_max}, n_eta={n_eta}: "
            + sol.message
        )
    return sol


def vk_profiles_dense(Re, vk_sol, r_obs=1.0, eta_plot_max=10.0, n_eta_plot=2000):
    """
    VKD solution on dense samples.
    OUTPUT: eta_dense, z_dense, U_dense, V_dense, W_dense

    Note: To be consistent with PINN output_transform:
      U = r*F
      V = r*(G-1)
      W = δ*H   (δ = Re^{-1/2})
    """
    delta_Re = Re ** (-0.5)

    eta_dense = np.linspace(0.0, eta_plot_max, n_eta_plot)
    y_vk = vk_sol.sol(eta_dense)  # (5, n_eta_plot)

    F = y_vk[0, :]
    G = y_vk[2, :]
    H = y_vk[4, :]

    z_dense = (delta_Re * eta_dense).reshape(-1, 1)

    U_dense = (r_obs * F).reshape(-1, 1)
    V_dense = (r_obs * (G - 1.0)).reshape(-1, 1)
    W_dense = (delta_Re * H).reshape(-1, 1)  

    return (eta_dense.reshape(-1, 1).astype(np.float64),
            z_dense.astype(np.float32),
            U_dense.astype(np.float32),
            V_dense.astype(np.float32),
            W_dense.astype(np.float32))


def select_obs_from_dense(eta_dense, z_dense, U_dense, V_dense, W_dense,
                          r_obs=1.0, n_obs=10):
    """
    It selects n_obs points from the dense profile and converts them to PINN PointSetBC format.
    """
    N = eta_dense.shape[0]
    idx = np.linspace(0, N - 1, n_obs).astype(int)

    z_obs = z_dense[idx]  # (n_obs,1)
    U_obs = U_dense[idx]
    V_obs = V_dense[idx]
    W_obs = W_dense[idx]

    X_obs = np.hstack([
        (r_obs * np.ones_like(z_obs)),
        z_obs
    ]).astype(np.float32)

    return X_obs, U_obs, V_obs, W_obs, z_obs, idx


# =========================================
# 2) PINN
# =========================================

device = torch_directml.device()
torch.set_default_device(device)
torch.set_default_dtype(torch.float32)

L = 10.0
r_min = 0.1
r_max = 1.0
geom = dde.geometry.Rectangle([r_min, 0.0], [r_max, L])

Re_list = [259, 752]

layer_sizes = [4]
neuron_sizes = [64]


# ---------------------------
# PDE
# ---------------------------
def make_pde(Re):
    def pde(x, y):
        r = x[:, 0:1]
        z = x[:, 1:2]

        U = y[:, 0:1]
        V = y[:, 1:2]
        W = y[:, 2:3]
        P = y[:, 3:4]

        U_r = dde.grad.jacobian(y, x, i=0, j=0)
        U_z = dde.grad.jacobian(y, x, i=0, j=1)
        V_r = dde.grad.jacobian(y, x, i=1, j=0)
        V_z = dde.grad.jacobian(y, x, i=1, j=1)
        W_r = dde.grad.jacobian(y, x, i=2, j=0)
        W_z = dde.grad.jacobian(y, x, i=2, j=1)
        P_r = dde.grad.jacobian(y, x, i=3, j=0)
        P_z = dde.grad.jacobian(y, x, i=3, j=1)

        U_rr = dde.grad.jacobian(U_r, x, j=0)
        U_zz = dde.grad.jacobian(U_z, x, j=1)
        V_rr = dde.grad.jacobian(V_r, x, j=0)
        V_zz = dde.grad.jacobian(V_z, x, j=1)
        W_rr = dde.grad.jacobian(W_r, x, j=0)
        W_zz = dde.grad.jacobian(W_z, x, j=1)

        # Rotating-disk PDEs
        eq1 = (1.0 / r) * (U + r * U_r) + W_z
        eq2 = U * U_r + W * U_z - (V + r) ** 2 / r - (1.0 / Re) * (
            U_zz + (1.0 / r) * U_r + U_rr - U / (r ** 2)
        ) + P_r
        eq3 = U * V_r + W * V_z + (U * V) / r + 2.0 * U - (1.0 / Re) * (
            V_zz + (1.0 / r) * V_r + V_rr - V / (r ** 2)
        )
        eq4 = U * W_r + W * W_z + P_z - (1.0 / Re) * (
            (1.0 / r) * W_r + W_rr + W_zz
        )


        return [eq1, eq2, eq3, eq4]

    return pde


# =====================================================
# Noise function + relative L2 error
# =====================================================

def add_gaussian_noise(field: np.ndarray,
                       noise_level: float,
                       rng: np.random.Generator) -> np.ndarray:
    """
    field: (N,1) numpy array
    noise_level: 0.01 -> ~%1 genlikte gürültü
    """
    if noise_level <= 0.0:
        return field.copy()

    scale = np.max(np.abs(field))
    if scale == 0.0:
        scale = 1.0

    noise = noise_level * scale * rng.standard_normal(field.shape).astype(np.float32)
    return (field + noise).astype(np.float32)


def relative_L2_error(pred: np.ndarray, ref: np.ndarray) -> float:
    diff = pred - ref
    num = np.sqrt(np.sum(diff**2))
    den = np.sqrt(np.sum(ref**2))
    if den == 0.0:
        return np.nan
    return float(num / den)


# =========================================
# 3) Training cycle
# =========================================
base_dir = "SmoothDisk_noise_sweep"
os.makedirs(base_dir, exist_ok=True)

noise_levels = [0.0]  # isterse [0.0, 0.01, 0.02, ...]

errors_csv = os.path.join(base_dir, "noise_sweep_errors_SMOOTHDISK.csv")
if not os.path.exists(errors_csv):
    with open(errors_csv, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow([
            "Re",
            "n_hidden_layers", "neurons_per_layer",
            "activation", "noise_level",
            "E_U_relL2", "E_V_relL2", "E_W_relL2", "E_comb_relL2",
            "u_prime_r1_z0", "v_prime_r1_z0", "w_r1_zL",
            "Rel_U", "Rel_V", "Rel_W",
        ])


for Re in Re_list:
    print(f"\n== PINN: Re={Re} ===")

    pde = make_pde(Re)
    delta_Re = Re ** (-0.5)

    # ---------------------------------------------------------
    # 1) Solve the VKD numerical solution within the range eta∈[0,10].
    # ---------------------------------------------------------
    vk_sol = solve_vkd(s_suction=0.0, eta_max=10.0, n_eta=800, tol=1e-8, max_nodes=200000)

    # ---------------------------------------------------------
    # 2) First create the dense profile, then select 10 points from the dense profile
    # ---------------------------------------------------------
    eta_dense, z_dense, U_dense, V_dense, W_dense = vk_profiles_dense(
        Re=Re,
        vk_sol=vk_sol,
        r_obs=1.0,
        eta_plot_max=10.0,
        n_eta_plot=2000
    )

    X_obs, U_obs_ref, V_obs_ref, W_obs_ref, z_obs, idx_obs = select_obs_from_dense(
        eta_dense=eta_dense,
        z_dense=z_dense,
        U_dense=U_dense,
        V_dense=V_dense,
        W_dense=W_dense,
        r_obs=1.0,
        n_obs=10
    )

    print("  X_obs shape:", X_obs.shape)
    print("  z range     :", float(z_obs.min()), "→", float(z_obs.max()))
    print("  U min/max   :", float(U_obs_ref.min()), "→", float(U_obs_ref.max()))
    print("  V min/max   :", float(V_obs_ref.min()), "→", float(V_obs_ref.max()))
    print("  W min/max   :", float(W_obs_ref.min()), "→", float(W_obs_ref.max()))

    # ---------------------------------------------------------
    # 3) Numerical solution graph: dense + selected 10 points overlay
    # ---------------------------------------------------------
    fig, axes = plt.subplots(1, 3, figsize=(12, 4), sharex=True)

    axes[0].plot(eta_dense[:, 0], U_dense[:, 0], linewidth=2, label="dense")
    axes[0].plot(eta_dense[idx_obs, 0], U_dense[idx_obs, 0], "o", label="obs(10)")
    axes[0].set_xlabel(r"$\eta$"); axes[0].set_ylabel("U(r=1,η)")
    axes[0].set_title("U (dense + obs)")

    axes[1].plot(eta_dense[:, 0], V_dense[:, 0], linewidth=2)
    axes[1].plot(eta_dense[idx_obs, 0], V_dense[idx_obs, 0], "o")
    axes[1].set_xlabel(r"$\eta$"); axes[1].set_ylabel("V(r=1,η)")
    axes[1].set_title("V (dense + obs)")

    axes[2].plot(eta_dense[:, 0], W_dense[:, 0], linewidth=2)
    axes[2].plot(eta_dense[idx_obs, 0], W_dense[idx_obs, 0], "o")
    axes[2].set_xlabel(r"$\eta$"); axes[2].set_ylabel("W(r=1,η)")
    axes[2].set_title("W (dense + obs)")

    plt.tight_layout()
    fig_dir = os.path.join(base_dir, "figs_obs")
    os.makedirs(fig_dir, exist_ok=True)
    fig.savefig(os.path.join(fig_dir, f"vk_dense_and_obs_eta_Re{int(Re)}.png"), dpi=200)
    plt.close(fig)

    # ---------------------------------------------------------
    # 4) Collocation anchors (smooth disk => entire domain)

    # =====================================================
    # Uniform GRID anchors (same budget with CC/CL anchors)
    # =====================================================

    target_N = 5000   

    r_span = float(r_max - r_min)
    L_span = float(L)

    # A choice to keep the grid spacing roughly isotropic (dr ~ dz):
    # Nz ≈ (L/r_span) * Nr  =>  N ≈ (L/r_span) * Nr^2  =>  Nr ≈ sqrt(N * r_span / L)
    Nr = max(2, int(np.round(np.sqrt(target_N * r_span / L_span))))
    Nz = max(2, int(np.round(target_N / Nr)))

    # Increase Nz so that N is at least target_N:
    while Nr * Nz < target_N:
        Nz += 1

    # Produce a uniform grid
    r_uni = np.linspace(r_min, r_max, Nr, dtype=np.float32)
    z_uni = np.linspace(0.0, L, Nz, dtype=np.float32)

    RRu, ZZu = np.meshgrid(r_uni, z_uni, indexing="xy")
    domain_uniform_grid = np.column_stack([RRu.ravel(), ZZu.ravel()]).astype(np.float32)

    print(f"[Uniform GRID] Nr={Nr}, Nz={Nz}, N={domain_uniform_grid.shape[0]} (target {target_N})")

    def feature_transform(x):
        r = x[:, 0:1]
        z = x[:, 1:2]
        eta = z / delta_Re
        return torch.cat([r, eta], dim=1)

    base_seed = 12345

    def eval_du_dz_dv_dz(net_local, r, z):
        x = torch.tensor([[r, z]], dtype=torch.float32, device=device, requires_grad=True)
        y = net_local(x)  # [U, V, W, P] (output_transform applied)
        U = y[:, 0:1]
        V = y[:, 1:2]
        dUdx = torch.autograd.grad(U, x, grad_outputs=torch.ones_like(U), retain_graph=True)[0]
        dVdx = torch.autograd.grad(V, x, grad_outputs=torch.ones_like(V), retain_graph=True)[0]
        dU_dz = dUdx[0, 1]
        dV_dz = dVdx[0, 1]
        return dU_dz.detach().cpu().item(), dV_dz.detach().cpu().item()

    def build_wall_points(r_vals: np.ndarray) -> np.ndarray:
        r_vals = np.asarray(r_vals, dtype=np.float32).reshape(-1)
        z_wall = np.zeros_like(r_vals, dtype=np.float32)
        return np.column_stack([r_vals, z_wall]).astype(np.float32)

    def build_top_points(r_vals: np.ndarray, L: float) -> np.ndarray:
        r_vals = np.asarray(r_vals, dtype=np.float32).reshape(-1)
        z_top = (L * np.ones_like(r_vals, dtype=np.float32))
        return np.column_stack([r_vals, z_top]).astype(np.float32)

    for l in layer_sizes:
        for neu in neuron_sizes:
            layers = [2] + [neu] * l + [4]
            act = "tanh"

            for noise_idx, noise_level in enumerate(noise_levels):
                print(f"\n[NOISE] Re={Re}, layers={l}, neu={neu}, noise={noise_level*100:.1f}%")

                rng = np.random.default_rng(base_seed + noise_idx)

                # Noisy observations (reference 10 points)
                U_obs = add_gaussian_noise(U_obs_ref, noise_level, rng)
                V_obs = add_gaussian_noise(V_obs_ref, noise_level, rng)
                W_obs = add_gaussian_noise(W_obs_ref, noise_level, rng)

                # obs data on the line r=1
                bc_U = dde.icbc.PointSetBC(X_obs, U_obs, component=0)
                bc_V = dde.icbc.PointSetBC(X_obs, V_obs, component=1)
                bc_W = dde.icbc.PointSetBC(X_obs, W_obs, component=2)
                R_nodes = torch.tensor(r_uni, dtype=torch.float32, device=device).cpu().numpy()
                # Wall and upper boundary points
                r_bc = R_nodes.copy().astype(np.float32)
                X_wall = build_wall_points(r_bc)
                X_top  = build_top_points(r_bc, float(L))

                zeros_wall = np.zeros((len(r_bc), 1), dtype=np.float32)

                # ---- Lower wall: no-slip U=V=W=0 ----
                bc_wall_U = dde.icbc.PointSetBC(X_wall, zeros_wall, component=0)
                bc_wall_V = dde.icbc.PointSetBC(X_wall, zeros_wall, component=1)
                bc_wall_W = dde.icbc.PointSetBC(X_wall, zeros_wall, component=2)

                # ---- Upper limit: U=0, V=-r, W=δ*H_inf ----
                # H_inf ~ -0.88230; W_inf = δ * H_inf
                target_top_U = np.zeros((len(r_bc), 1), dtype=np.float32)
                target_top_V = (-r_bc.reshape(-1, 1)).astype(np.float32)
                target_top_W = (delta_Re * (-0.88230) * np.ones((len(r_bc), 1), dtype=np.float32))

                bc_top_U = dde.icbc.PointSetBC(X_top, target_top_U, component=0)
                bc_top_V = dde.icbc.PointSetBC(X_top, target_top_V, component=1)
                bc_top_W = dde.icbc.PointSetBC(X_top, target_top_W, component=2)

                # ---- Wall derivative targets: δ U_z = r F'(0), δ V_z = r G'(0) ----
                zeros_op = np.zeros((X_wall.shape[0], 1), dtype=np.float32)

                def op_U_eta(x, y, *args):
                    r = x[:, 0:1]
                    U_z = dde.grad.jacobian(y, x, i=0, j=1)
                    return delta_Re * U_z - 0.51023 * r

                def op_V_eta(x, y, *args):
                    r = x[:, 0:1]
                    V_z = dde.grad.jacobian(y, x, i=1, j=1)
                    return delta_Re * V_z + 0.61592 * r  # G'(0)=-0.61592

                bc_wall_Ueta = dde.icbc.PointSetOperatorBC(X_wall, zeros_op, op_U_eta)
                bc_wall_Veta = dde.icbc.PointSetOperatorBC(X_wall, zeros_op, op_V_eta)

                bcs = [
                    bc_U, bc_V, bc_W,
                    bc_wall_U, bc_wall_V, bc_wall_W,
                    bc_wall_Ueta, bc_wall_Veta,
                    bc_top_U, bc_top_V, bc_top_W,
                ]

                data = dde.data.PDE(
                    geom, pde, bcs,
                    num_domain=5000,
                    num_boundary=0,
                    num_test=1500,
                    anchors=None,
                )

                net = dde.nn.FNN(layers, act, "Glorot uniform")
                net.apply_feature_transform(feature_transform)

                def output_transform(x, y):
                    r = x[:, 0:1]
                    U = r * y[:, 0:1]
                    V = r * y[:, 1:2]
                    W = delta_Re * y[:, 2:3]          # W = δ*H
                    P = (delta_Re ** 2) * y[:, 3:4]
                    return torch.cat([U, V, W, P], dim=1)

                net.apply_output_transform(output_transform)
                net.to(device)

                output_dir = os.path.join(
                    base_dir,
                    f"Re{int(Re)}_{neu}x{l}_noise{int(noise_level*100)}pct"
                )
                os.makedirs(output_dir, exist_ok=True)

                model = dde.Model(data, net)
                model.compile("adam", lr=5e-4)

                losshistory_adam, train_state_adam = model.train(
                    iterations=5000,
                    model_save_path=os.path.join(output_dir, "model_adam"),
                    verbose=1,
                    display_every=500,
                )
                dde.saveplot(
                    losshistory_adam, train_state_adam,
                    issave=True, isplot=True, output_dir=output_dir
                )

                # Far-field control: r=1, z=L
                with torch.no_grad():
                    x_w = torch.tensor([[1.0, L]], dtype=torch.float32, device=device)
                    y_w = net(x_w)  # [U, V, W, P]
                    w_r1_zL = y_w[0, 2].item()

                # --- Dense evaluation grid (r=1, eta in [0,10]) ---
                delta_Re = Re ** (-0.5)

                eta_dense = np.linspace(0.0, 10.0, 400).astype(np.float64)
                z_dense   = (delta_Re * eta_dense).reshape(-1, 1).astype(np.float32)
                r_dense   = (1.0 * np.ones_like(z_dense)).astype(np.float32)
                X_dense   = np.hstack([r_dense, z_dense]).astype(np.float32)

                # Dense grid on mesh estimation (physical U, V, W due to output_transform being applied)
                Y_dense = model.predict(X_dense)
                U_pred_dense = Y_dense[:, 0:1]
                V_pred_dense = Y_dense[:, 1:2]
                W_pred_dense = Y_dense[:, 2:3]  # W

                # Reference on the SAME eta_dense
                Y_vk_dense = vk_sol.sol(eta_dense)
                F_dense = Y_vk_dense[0, :]
                G_dense = Y_vk_dense[2, :]
                H_dense = Y_vk_dense[4, :]

                U_ref_dense = (1.0 * F_dense).reshape(-1, 1).astype(np.float32)
                V_ref_dense = (1.0 * (G_dense - 1.0)).reshape(-1, 1).astype(np.float32)
                W_ref_dense = (delta_Re * H_dense).reshape(-1, 1).astype(np.float32)  # physical W = delta*H

                E_U = relative_L2_error(U_pred_dense, U_ref_dense)
                E_V = relative_L2_error(V_pred_dense, V_ref_dense)
                E_W = relative_L2_error(W_pred_dense, W_ref_dense)
                E_comb = relative_L2_error(
                    np.hstack([U_pred_dense, V_pred_dense, W_pred_dense]),
                    np.hstack([U_ref_dense, V_ref_dense, W_ref_dense]),
                )

                u_prime_r1_z0, v_prime_r1_z0 = eval_du_dz_dv_dz(net, 1.0, 0.0)

                u_num_z = 0.51023 / delta_Re
                v_num_z = -0.61592 / delta_Re
                w_num   = delta_Re * (-0.88230)   # w∞

                Rel_U = abs(u_prime_r1_z0 - u_num_z) / abs(u_num_z)
                Rel_V = abs(v_prime_r1_z0 - v_num_z) / abs(v_num_z)
                Rel_W = abs(w_r1_zL - w_num) / (abs(w_num) if abs(w_num) > 0 else np.nan)

                E_comb = relative_L2_error(
                    np.hstack([U_pred_dense, V_pred_dense, W_pred_dense]),
                    np.hstack([U_ref_dense, V_ref_dense, W_ref_dense]),
                )

                print(
                    f"[ERROR] noise={noise_level*100:.1f}%  "
                    f"E_U={E_U:.5e}, E_V={E_V:.5e}, E_W={E_W:.5e}, "
                    f"E_comb={E_comb:.5e}, "
                    f"u_prime={u_prime_r1_z0:.6f}, v_prime={v_prime_r1_z0:.6f}, w_r1_zL={w_r1_zL:.6f}, "
                    f"Rel_U={Rel_U:.5e}, Rel_V={Rel_V:.5e}, Rel_W={Rel_W:.5e}"
                )

                with open(errors_csv, "a", newline="") as f:
                    writer = csv.writer(f)
                    writer.writerow([
                        Re,
                        l, neu,
                        act, noise_level,
                        E_U, E_V, E_W, E_comb,
                        u_prime_r1_z0, v_prime_r1_z0, w_r1_zL,
                        Rel_U, Rel_V, Rel_W,
                    ])
# Out:
# == PINN: Re=259 ===
#   X_obs shape: (10, 2)
#   z range     : 0.0 → 0.6213697791099548
#   U min/max   : -8.9297161204846e-25 → 0.17732223868370056
#   V min/max   : -1.0 → 0.0
#   W min/max   : -0.05482321232557297 → 0.0
# [Uniform GRID] Nr=21, Nz=239, N=5019 (target 5000)
#
# [NOISE] Re=259, layers=4, neu=64, noise=0.0%
# ...
# Compiling model...
# 'compile' took 0.000141 s
#
# Training model...
#
# Step      Train loss                                                                                                                                                Test loss                                                                                                                                                 Test metric
# ...

# %%
Re_list = [196, 259, 391,471, 555.0, 568, 615, 648, 713, 752]
r_min, r_max = 0.1, 1.0
L = 10.0

base_dir = "SmoothDisk_noise_sweep"
compare_fig_dir = "SmoothDisk_noise_sweep/VKD_PINN_compare_raw"
os.makedirs(compare_fig_dir, exist_ok=True)

# --- Weight loading functions ---
def try_restore_ckpt(model, outdir):
    for fname in sorted(os.listdir(outdir)):
        if fname.endswith(".ckpt"):
            ckpt_path = os.path.join(outdir, fname)
            try:
                model.restore(ckpt_path, verbose=0)
                return True, ("ckpt", ckpt_path)
            except Exception:
                pass
    return False, None

def try_load_pt(net, outdir):
    for name in [
        "model_adam-10000.pt",
        "model_adam-5000.pt",
        "model_adam-600.pt",
        "model_adam.pt",
        "model_final.pt",
        "model_bfgs-3810.pt",
    ]:
        p = os.path.join(outdir, name)
        if os.path.isfile(p):
            state = torch.load(p, map_location=device)
            for cand in [
                state,
                isinstance(state, dict) and state.get("model_state_dict"),
                isinstance(state, dict) and state.get("state_dict"),
                isinstance(state, dict) and state.get("net"),
            ]:
                if isinstance(cand, dict):
                    try:
                        net.load_state_dict(cand, strict=True)
                        return True, ("pt", p)
                    except Exception:
                        pass
    return False, None

for i, Re in enumerate(Re_list):
    Re_val = float(Re)
    delta = Re_val ** (-0.5) 

    print(f"\n=== Re = {Re_val:.1f} ===")
    print(f"delta = {delta:.6f}")

    # Network architecture
    layers = [2] + [64] * 4 + [4]
    net = dde.nn.FNN(layers, "tanh", "Glorot uniform")

    # Feature and output transforms
    def feature_transform(x, delta=delta):
        r = x[:, 0:1]
        z = x[:, 1:2]
        eta = z / delta
        return torch.cat([r, eta], dim=1)

    def output_transform(x, y, delta=delta):
        r = x[:, 0:1]
        U = r * y[:, 0:1]           # U = r f(η)
        V = r * y[:, 1:2]           # V = r (g(η)-1)
        W = delta * y[:, 2:3]       # W = δ w̄(η)
        P = (delta**2) * y[:, 3:4]
        return torch.cat([U, V, W, P], dim=1)

    net.apply_feature_transform(feature_transform)
    net.apply_output_transform(output_transform)
    net.to(device)

    #Model
    geom = dde.geometry.Rectangle([r_min, 0.0], [r_max, L])
    dummy_data = dde.data.PDE(geom, lambda x, y: [y], [], num_domain=0, num_boundary=0)
    model = dde.Model(dummy_data, net)
    model.compile("adam", lr=1e-3)

    # Load the weights 
    output_dir = os.path.join(base_dir, f"Re{int(Re)}_{neu}x{l}_noise{int(noise_level*100)}pct")
    if not os.path.isdir(output_dir):
        raise FileNotFoundError(f"Dizin yok: {output_dir}")

    ok, src = try_restore_ckpt(model, output_dir)
    if not ok:
        ok, src = try_load_pt(net, output_dir)
    if not ok:
        raise FileNotFoundError(
            f"Ağırlık bulunamadı: {output_dir} altında .ckpt veya model_adam-*.pt yok."
        )

    print(f"Yüklendi: {src[0]} -> {src[1]}")



    X = domain_uniform_grid  
    Y = model.predict(X)

    r = X[:,0]
    z = X[:,1]
    eta = z / delta_Re

    U = Y[:,0]
    V = Y[:,1]
    W = Y[:,2]



    delta_Re = Re**(-0.5)

    eta_dense = np.linspace(0.0, 10.0, 400)
    z_dense   = (delta_Re * eta_dense).reshape(-1,1).astype(np.float32)
    r_dense   = (1.0 * np.ones_like(z_dense)).astype(np.float32)

    X_dense = np.hstack([r_dense, z_dense]).astype(np.float32)

    # Network prediction (Physical U, V, W rotate; with output_transform applied)
    Yp = model.predict(X_dense)
    U_net = Yp[:,0]
    V_net = Yp[:,1]
    W_net = Yp[:,2]/delta_Re

    # Reference (via the same eta_dense)
    y_vk = vk_sol.sol(eta_dense)
    F = y_vk[0,:]
    G = y_vk[2,:]
    H = y_vk[4,:]

    U_ref = 1.0 * F
    V_ref = 1.0 * (G - 1.0)
    W_ref = H

    plt.figure(); plt.plot(eta_dense, U_ref, label="ref"); plt.plot(eta_dense, U_net, "--", label="net");   plt.title(r"$\hat{u}$"); plt.legend(); plt.xlabel(r"$\eta$")
    plt.figure(); plt.plot(eta_dense, V_ref, label="ref"); plt.plot(eta_dense, V_net, "--", label="net");   plt.title(r"$\hat{v}$"); plt.legend(); plt.xlabel(r"$\eta$")
    plt.figure(); plt.plot(eta_dense, W_ref, label="ref"); plt.plot(eta_dense, W_net, "--", label="net");  plt.title(r"$\hat{w}$"); plt.legend(); plt.xlabel(r"$\eta$")
    plt.show()


    # -----------------------------
    # DENSE evaluation on eta in [0,10] at r=1
    # -----------------------------
    delta_Re = Re ** (-0.5)

    eta_dense = np.linspace(0.0, 10.0, 400).astype(np.float64)
    z_dense = (delta_Re * eta_dense).reshape(-1, 1).astype(np.float32)
    r_dense = (1.0 * np.ones_like(z_dense)).astype(np.float32)
    X_dense = np.hstack([r_dense, z_dense]).astype(np.float32)

    # Net prediction (output_transform already applied -> physical U,V,W,P)
    Y_dense = model.predict(X_dense)
    U_net_dense = Y_dense[:, 0:1]
    V_net_dense = Y_dense[:, 1:2]
    W_net_dense = Y_dense[:, 2:3]/delta_Re

    # Reference from VK similarity at same eta_dense
    Y_vk_dense = vk_sol.sol(eta_dense)  # (5, N)
    F_dense = Y_vk_dense[0, :]
    G_dense = Y_vk_dense[2, :]
    H_dense = Y_vk_dense[4, :]

    U_ref_dense = (1.0 * F_dense).reshape(-1, 1).astype(np.float32)
    V_ref_dense = (1.0 * (G_dense - 1.0)).reshape(-1, 1).astype(np.float32)
    W_ref_dense = (H_dense).reshape(-1, 1).astype(np.float32)  # W scaled

    E_U_dense = relative_L2_error(U_net_dense, U_ref_dense)
    E_V_dense = relative_L2_error(V_net_dense, V_ref_dense)
    E_W_dense = relative_L2_error(W_net_dense, W_ref_dense)
    E_comb_dense = relative_L2_error(
        np.hstack([U_net_dense, V_net_dense, W_net_dense]),
        np.hstack([U_ref_dense, V_ref_dense, W_ref_dense]),
    )

    print(f"[DENSE ERROR eta∈[0,10]] "
        f"E_U={E_U_dense:.5e}, E_V={E_V_dense:.5e}, E_W={E_W_dense:.5e}, E_comb={E_comb_dense:.5e}")
    import numpy as np
    import torch

    # -----------------------------
    # Wall derivatives -> F'(0), G'(0)   and   far-field -> H(infty)
    # -----------------------------
    delta_Re = Re ** (-0.5)

    # --- Reference values from VK solution ---
    # y = [F, F', G, G', H]
    Fp_ref = float(vk_sol.sol(0.0)[1])   # F'(0)
    Gp_ref = float(vk_sol.sol(0.0)[3])   # G'(0)

    eta_far = float(vk_sol.x[-1])        # use last available eta as "infty"
    Hinf_ref = float(vk_sol.sol(eta_far)[4])

    # --- Network values from wall gradients at (r=1, z=0) ---
    # net(x) returns physical outputs [U,V,W,P] because of output_transform
    x0 = torch.tensor([[1.0, 0.0]], dtype=torch.float32, device=device, requires_grad=True)
    y0 = net(x0)
    U0 = y0[:, 0:1]
    V0 = y0[:, 1:2]

    # dU/dz, dV/dz at the wall
    gradU = torch.autograd.grad(U0, x0, grad_outputs=torch.ones_like(U0), retain_graph=True)[0]
    gradV = torch.autograd.grad(V0, x0, grad_outputs=torch.ones_like(V0), retain_graph=True)[0]
    Uz0 = gradU[0, 1]
    Vz0 = gradV[0, 1]

    # Convert physical wall gradients to similarity derivatives:
    # U = r F(eta), eta = z/delta => dU/dz = r * F'(eta) * (1/delta)
    # => F'(0) = delta * (dU/dz) / r
    r0 = 1.0
    Fp_hat = float((delta_Re * Uz0 / r0).detach().cpu().item())
    Gp_hat = float((delta_Re * Vz0 / r0).detach().cpu().item())

    # --- Network H(infty) from top point (r=1, z=L): H = W/delta ---
    xL = torch.tensor([[1.0, float(L)]], dtype=torch.float32, device=device)
    with torch.no_grad():
        yL = net(xL)
        W_phys_L = yL[0, 2].item()        # physical W at z=L
    Hinf_hat = float(W_phys_L / delta_Re)

    # --- Relative errors (scalar "relative L2") ---
    def rel_err(a, b, eps=1e-14):
        den = max(abs(b), eps)
        return abs(a - b) / den

    Rel_Fp = rel_err(Fp_hat, Fp_ref)
    Rel_Gp = rel_err(Gp_hat, Gp_ref)
    Rel_Hinf = rel_err(Hinf_hat, Hinf_ref)

    print(f"[WALL/FF CHECK] "
        f"F'(0): ref={Fp_ref:.8f}, net={Fp_hat:.8f}, Rel={Rel_Fp:.5e} | "
        f"G'(0): ref={Gp_ref:.8f}, net={Gp_hat:.8f}, Rel={Rel_Gp:.5e} | "
        f"H(∞≈η={eta_far:.2f}): ref={Hinf_ref:.8f}, net={Hinf_hat:.8f}, Rel={Rel_Hinf:.5e}")


    import numpy as np
    import matplotlib.pyplot as plt

    delta_Re = Re ** (-0.5)

    # dense grid in (r, eta)
    Nr_plot = 80
    Neta_plot = 120
    r_lin   = np.linspace(r_min, r_max, Nr_plot).astype(np.float64)
    eta_lin = np.linspace(0.0, 10.0, Neta_plot).astype(np.float64)

    R, ETA = np.meshgrid(r_lin, eta_lin, indexing="xy")
    Z = (delta_Re * ETA).astype(np.float64)

    X_grid = np.column_stack([R.reshape(-1), Z.reshape(-1)]).astype(np.float32)
    Y_grid = model.predict(X_grid)

    U_hat = Y_grid[:, 0].reshape(R.shape)
    V_hat = Y_grid[:, 1].reshape(R.shape)
    W_hat = (Y_grid[:, 2]/delta_Re).reshape(R.shape)   # physical (scaled)

    def style_3d(ax):
        ax.set_xlabel("r", labelpad=8)
        ax.set_ylabel(r"$\eta$", labelpad=8)
        ax.view_init(elev=25, azim=-60)

        # soften the "boxy" look
        ax.xaxis.pane.fill = False
        ax.yaxis.pane.fill = False
        ax.zaxis.pane.fill = False
        ax.grid(True, alpha=0.25)

        # reduce pane border lines
        ax.xaxis.pane.set_edgecolor((0, 0, 0, 0.15))
        ax.yaxis.pane.set_edgecolor((0, 0, 0, 0.15))
        ax.zaxis.pane.set_edgecolor((0, 0, 0, 0.15))

    fig = plt.figure(figsize=(18, 5), constrained_layout=True)
    axs = [
        fig.add_subplot(1, 3, 1, projection="3d"),
        fig.add_subplot(1, 3, 2, projection="3d"),
        fig.add_subplot(1, 3, 3, projection="3d"),
    ]

    # Colour map selection
    cmap = "viridis"

    # U
    style_3d(axs[0])
    surf0 = axs[0].plot_surface(
        R, ETA, U_hat,
        cmap=cmap,
        linewidth=0,
        antialiased=True,
        shade=True,
        alpha=0.97
    )
    cbar0 = fig.colorbar(surf0, ax=axs[0], shrink=0.65, pad=0.08)
    cbar0.set_label(r"$\hat{u}$", rotation=0, labelpad=18)
    cbar0.ax.yaxis.set_label_position("right")

    # V
    style_3d(axs[1])
    surf1 = axs[1].plot_surface(
        R, ETA, V_hat,
        cmap=cmap,
        linewidth=0,
        antialiased=True,
        shade=True,
        alpha=0.97
    )
    cbar1 = fig.colorbar(surf1, ax=axs[1], shrink=0.65, pad=0.08)
    cbar1.set_label(r"$\hat{v}$", rotation=0, labelpad=18)
    cbar1.ax.yaxis.set_label_position("right")

    # W (physical, scaled)
    style_3d(axs[2])
    surf2 = axs[2].plot_surface(
        R, ETA, W_hat,
        cmap=cmap,
        linewidth=0,
        antialiased=True,
        shade=True,
        alpha=0.97
    )
    cbar2 = fig.colorbar(surf2, ax=axs[2], shrink=0.65, pad=0.10)  # Make the pad a bit larger so the right edge doesn't get trimmed off.
    cbar2.set_label(r"$\hat{w}$", rotation=0, labelpad=18)
    cbar2.ax.yaxis.set_label_position("right")

    plt.show()


# ============================================================
# FINAL: Reference in a single figure + 50 points for each Re (r=1, η∈[0,10])
# ============================================================
import glob

# --- The output folder is secure ---
def resolve_output_dir(base_dir, Re_int):
    cand = []


    try:
        cand.append(os.path.join(
            base_dir,
            f"Re{Re_int}_{neu}x{l}_noise{int(noise_level*100)}pct"
        ))
        cand.append(os.path.join(
            base_dir,
            f"Re{Re_int}_{neu}x{l}_noise{int(noise_level*100)}pct_Nr{N_r}_Nz{N_z}"
        ))
    except Exception:
        pass

    cand += [
        os.path.join(base_dir, f"Re{Re_int}_64x4_noise0pct"),
        os.path.join(base_dir, f"Re{Re_int}_64x4_noise0pct_Nr{N_r}_Nz{N_z}") if "N_r" in globals() else "",
    ]
    cand = [c for c in cand if c and os.path.isdir(c)]
    if cand:
        return cand[0]

    # 3) Fallback: search with glob (Take the first folder containing noise0)
    hits = sorted(glob.glob(os.path.join(base_dir, f"Re{Re_int}_*noise0*")))
    hits = [h for h in hits if os.path.isdir(h)]
    if hits:
        return hits[0]

    raise FileNotFoundError(f"Uygun output_dir bulunamadı: base_dir={base_dir}, Re={Re_int}")
# Out:
# === Re = 196.0 ===
# delta = 0.071429
# Compiling model...
# 'compile' took 0.000114 s
#
# Yüklendi: pt -> SmoothDisk_noise_sweep\Re196_64x4_noise0pct\model_adam-5000.pt
# ...

# %%
import matplotlib.pyplot as plt

# ============================================================
# LAYOUT: left v (top) + w (bottom), right u (spans two lines)
# ============================================================
fig = plt.figure(figsize=(18, 6), dpi=150)
gs = fig.add_gridspec(
    nrows=2, ncols=2,
    width_ratios=[1.0, 1.35],   # The right side is a bit wider.
    height_ratios=[1.0, 1.0],
    wspace=0.25, hspace=0.18
)

axV = fig.add_subplot(gs[0, 0])     # top left
axW = fig.add_subplot(gs[1, 0], sharex=axV)  # bottom left (x partner)
axU = fig.add_subplot(gs[:, 1])     # right column, spans two rows

# Reference lines
axU.plot(eta_dense, U_ref_dense, lw=2.5, label="von Kármán (ref)")
axV.plot(eta_dense, V_ref_dense, lw=2.5, label="von Kármán (ref)")
axW.plot(eta_dense, W_ref_dense, lw=2.5, label="von Kármán (ref)")



# Axis labels / grid
for ax in [axU, axV, axW]:
    ax.grid(True, linestyle="--", alpha=0.35)

axU.set_xlabel(r"$z$")
axV.set_xlabel("")             
axW.set_xlabel(r"$z$")        

axU.set_ylabel(r"$\hat{u}(r=1, z)$")
axV.set_ylabel(r"$\hat{v}(r=1, z)$")
axW.set_ylabel(r"$\hat{w}(r=1, z)$")

# Hide x tick labels in the upper subplot
plt.setp(axV.get_xticklabels(), visible=False)


markers = ["o", "s", "^", "D", "P", "X", "v", "<", ">", "*"]

eta_dense = np.linspace(0.0, 10.0, 400).astype(np.float64)
idx50 = np.linspace(0, eta_dense.size - 1, 50, dtype=int)

for i, Re in enumerate(Re_list):
    Re_val = float(Re)
    Re_int = int(Re_val)
    delta = Re_val ** (-0.5)

    m = markers[i % len(markers)]

    layers = [2] + [64] * 4 + [4]
    net = dde.nn.FNN(layers, "tanh", "Glorot uniform")

    def feature_transform(x, delta=delta):
        r = x[:, 0:1]
        z = x[:, 1:2]
        eta = z / delta
        return torch.cat([r, eta], dim=1)

    def output_transform(x, y, delta=delta):
        r = x[:, 0:1]
        U = r * y[:, 0:1]
        V = r * y[:, 1:2]
        W = delta * y[:, 2:3]
        P = (delta**2) * y[:, 3:4]
        return torch.cat([U, V, W, P], dim=1)

    net.apply_feature_transform(feature_transform)
    net.apply_output_transform(output_transform)
    net.to(device)

    geom = dde.geometry.Rectangle([r_min, 0.0], [r_max, L])
    dummy_data = dde.data.PDE(geom, lambda x, y: [y], [], num_domain=0, num_boundary=0)
    model = dde.Model(dummy_data, net)
    model.compile("adam", lr=1e-3)

    output_dir = resolve_output_dir(base_dir, Re_int)

    ok, src = try_restore_ckpt(model, output_dir)
    if not ok:
        ok, src = try_load_pt(net, output_dir)
    if not ok:
        raise FileNotFoundError(f"Ağırlık bulunamadı: {output_dir}")

    print(f"[LOAD] Re={Re_int} -> {src[0]} : {src[1]}")

    z_dense = (delta * eta_dense).reshape(-1, 1).astype(np.float32)
    r_dense = np.ones_like(z_dense, dtype=np.float32)
    X_dense = np.hstack([r_dense, z_dense]).astype(np.float32)

    Yp = model.predict(X_dense)
    U_hat = Yp[:, 0]
    V_hat = Yp[:, 1]
    W_hat = Yp[:, 2] / delta

    lbl = f"Re={Re_int}"
    axU.scatter(eta_dense[idx50], U_hat[idx50], s=22, marker=m, alpha=0.80, label=lbl)
    axV.scatter(eta_dense[idx50], V_hat[idx50], s=22, marker=m, alpha=0.80, label="_nolegend_")
    axW.scatter(eta_dense[idx50], W_hat[idx50], s=22, marker=m, alpha=0.80, label="_nolegend_")

handles, labels = axU.get_legend_handles_labels()

leg = axU.legend(
    handles, labels,
    loc="upper right",
    fontsize=7,
    ncol=1,                 
    frameon=True,
    fancybox=True,
    framealpha=0.9,
    borderpad=0.4,
    labelspacing=0.3,
    handlelength=1.2,
    handletextpad=0.4
)

# To make the legend box more like a "small rectangle":
leg.get_frame().set_linewidth(0.8)

fig.tight_layout()

out_png = os.path.join(compare_fig_dir, "VKD_ref_plus_PINN_scatter_allRe_eta0_10_layoutVW_left_U_right.png")
out_pdf = os.path.join(compare_fig_dir, "VKD_ref_plus_PINN_scatter_allRe_eta0_10_layoutVW_left_U_right.pdf")
fig.savefig(out_png, dpi=200)
fig.savefig(out_pdf)
plt.show()

print(f"[SAVED] {out_png}")
print(f"[SAVED] {out_pdf}")
# Out:
# Compiling model...
# 'compile' took 0.000264 s
#
# [LOAD] Re=196 -> pt : SmoothDisk_noise_sweep\Re196_64x4_noise0pct\model_adam-5000.pt
# Compiling model...
# 'compile' took 0.000100 s
#
# [LOAD] Re=259 -> pt : SmoothDisk_noise_sweep\Re259_64x4_noise0pct\model_adam-5000.pt
# Compiling model...
# 'compile' took 0.000096 s
#
# [LOAD] Re=391 -> pt : SmoothDisk_noise_sweep\Re391_64x4_noise0pct\model_adam-5000.pt
# Compiling model...
# 'compile' took 0.000092 s
#
# [LOAD] Re=471 -> pt : SmoothDisk_noise_sweep\Re471_64x4_noise0pct\model_adam-5000.pt
# Compiling model...
# 'compile' took 0.000099 s
#
# [LOAD] Re=555 -> pt : SmoothDisk_noise_sweep\Re555_64x4_noise0pct\model_adam-5000.pt
# Compiling model...
# 'compile' took 0.000102 s
#
# [LOAD] Re=568 -> pt : SmoothDisk_noise_sweep\Re568_64x4_noise0pct\model_adam-5000.pt
# Compiling model...
# 'compile' took 0.000102 s
#
# [LOAD] Re=615 -> pt : SmoothDisk_noise_sweep\Re615_64x4_noise0pct\model_adam-5000.pt
# Compiling model...
# ...

# %%
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
import torch
import deepxde as dde

# ------------------------------------------------------------
# 0) User settings
# ------------------------------------------------------------
Re_target = 196           
base_dir = "SmoothDisk_noise_sweep"
compare_fig_dir = os.path.join(base_dir, "Similarity_profiles_singleRe")
os.makedirs(compare_fig_dir, exist_ok=True)

r_min, r_max = 0.1, 1.0
L = 10.0

Nr_samples = 5
r_samples = np.linspace(r_min, r_max, Nr_samples)  # [0.1, ..., 1.0]

eta_max_plot = 10.0
Neta_plot = 400
eta_grid = np.linspace(0.0, eta_max_plot, Neta_plot).astype(np.float64)

# ------------------------------------------------------------
# 1) Weight loading aids
# ------------------------------------------------------------
def try_restore_ckpt(model, outdir):
    for fname in sorted(os.listdir(outdir)):
        if fname.endswith(".ckpt"):
            ckpt_path = os.path.join(outdir, fname)
            try:
                model.restore(ckpt_path, verbose=0)
                return True, ("ckpt", ckpt_path)
            except Exception:
                pass
    return False, None

def try_load_pt(net, outdir):
    for name in [
        "model_adam-10000.pt",
        "model_adam-5000.pt",
        "model_adam-1500.pt",
        "model_adam-600.pt",
        "model_adam.pt",
        "model_final.pt",
        "model_bfgs-3810.pt",
    ]:
        p = os.path.join(outdir, name)
        if os.path.isfile(p):
            state = torch.load(p, map_location="cpu")
            for cand in [
                state,
                isinstance(state, dict) and state.get("model_state_dict"),
                isinstance(state, dict) and state.get("state_dict"),
                isinstance(state, dict) and state.get("net"),
            ]:
                if isinstance(cand, dict):
                    try:
                        net.load_state_dict(cand, strict=True)
                        return True, ("pt", p)
                    except Exception:
                        pass
    return False, None

def resolve_output_dir(base_dir, Re_int):
    hits = sorted(glob.glob(os.path.join(base_dir, f"Re{Re_int}_*")))
    hits = [h for h in hits if os.path.isdir(h)]
    if not hits:
        raise FileNotFoundError(f"Output klasörü bulunamadı: {base_dir}/Re{Re_int}_*")
    return hits[0]


try:
    import torch_directml
    device = torch_directml.device()
except Exception:
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

torch.set_default_device(device)
torch.set_default_dtype(torch.float32)

# ------------------------------------------------------------
# 2) Set up the model + load (single Re)
# ------------------------------------------------------------
Re_val = float(Re_target)
Re_int = int(Re_val)
delta = Re_val ** (-0.5)        # delta_Re

layers = [2] + [64] * 4 + [4]
net = dde.nn.FNN(layers, "tanh", "Glorot uniform")

def feature_transform(x, delta=delta):
    r = x[:, 0:1]
    z = x[:, 1:2]
    eta = z / delta
    return torch.cat([r, eta], dim=1)

def output_transform(x, y, delta=delta):
    r = x[:, 0:1]
    U = r * y[:, 0:1]
    V = r * y[:, 1:2]
    W = delta * y[:, 2:3]     
    P = (delta**2) * y[:, 3:4]
    return torch.cat([U, V, W, P], dim=1)

net.apply_feature_transform(feature_transform)
net.apply_output_transform(output_transform)
net.to(device)

geom = dde.geometry.Rectangle([r_min, 0.0], [r_max, L])
dummy_data = dde.data.PDE(geom, lambda x, y: [y], [], num_domain=0, num_boundary=0)
model = dde.Model(dummy_data, net)
model.compile("adam", lr=1e-3)

output_dir = resolve_output_dir(base_dir, Re_int)
ok, src = try_restore_ckpt(model, output_dir)
if not ok:
    ok, src = try_load_pt(net, output_dir)
if not ok:
    raise FileNotFoundError(f"Ağırlık yüklenemedi: {output_dir}")

print(f"[LOAD] Re={Re_int} -> {src[0]} : {src[1]}")

# ------------------------------------------------------------
# 4) Generate profiles: Uhat, Vhat, What (on the eta axis)
# ------------------------------------------------------------
# Input production: z = delta * eta
z_grid = (delta * eta_grid).reshape(-1, 1).astype(np.float32)

U_profiles = {}
V_profiles = {}
W_profiles = {}
U_test = {}     # U/r
V_test = {}     # V/r
H_test = {}     # W/delta  (similarity H)

for r0 in r_samples:
    r_col = (r0 * np.ones_like(z_grid)).astype(np.float32)
    X = np.hstack([r_col, z_grid]).astype(np.float32)

    Yp = model.predict(X)              # physical [U,V,W,P]
    Uhat = Yp[:, 0]
    Vhat = Yp[:, 1]
    What = Yp[:, 2]

    U_profiles[r0] = Uhat
    V_profiles[r0] = Vhat
    W_profiles[r0] = What

    # similarity test:
    U_test[r0] = Uhat / r0
    V_test[r0] = Vhat / r0
    H_test[r0] = What / delta          # H(eta)

# ------------------------------------------------------------
# 5) Plot
# ------------------------------------------------------------
plt.rcParams.update({
    "font.size": 10,
    "axes.grid": True,
    "grid.alpha": 0.25
})

fig = plt.figure(figsize=(12, 10), dpi=140)
gs = fig.add_gridspec(3, 2, height_ratios=[1, 1, 1.05], hspace=0.35, wspace=0.28)

axU  = fig.add_subplot(gs[0, 0])
axUt = fig.add_subplot(gs[0, 1])
axV  = fig.add_subplot(gs[1, 0])
axVt = fig.add_subplot(gs[1, 1])
axW  = fig.add_subplot(gs[2, 0])
axWt = fig.add_subplot(gs[2, 1])

z_axis = (delta * eta_grid)  # z = delta * eta

# --- U(r,z)
for r0 in r_samples:
    axU.plot(z_axis, U_profiles[r0], lw=1.0, label=f"r={r0:.2f}")
axU.set_xlabel("z")
axU.set_ylabel(r"$\hat{u}(r,z)$")
axU.legend(fontsize=8, ncol=2, frameon=True)

# --- U similarity: U/r
for r0 in r_samples:
    axUt.plot(z_axis, U_test[r0], lw=1.0, label=f"r={r0:.2f}")
axUt.set_xlabel("z")
axUt.set_ylabel(r"$\hat{u}(r,z)/r$")
axUt.legend(fontsize=8, ncol=2, frameon=True)

# --- V(r,z)
for r0 in r_samples:
    axV.plot(z_axis, V_profiles[r0], lw=1.0, label=f"r={r0:.2f}")
axV.set_xlabel("z")
axV.set_ylabel(r"$\hat{v}(r,z)$")
axV.legend(fontsize=8, ncol=2, frameon=True)

# --- V similarity: V/r
for r0 in r_samples:
    axVt.plot(z_axis, V_test[r0], lw=1.0, label=f"r={r0:.2f}")
axVt.set_xlabel("z")
axVt.set_ylabel(r"$\hat{v}(r,z)/r$")
axVt.legend(fontsize=8, ncol=2, frameon=True)

# --- W(r,z) (physical W)
for r0 in r_samples:
    axW.plot(z_axis, W_profiles[r0], lw=1.0, label=f"r={r0:.2f}")
axW.set_xlabel("z")
axW.set_ylabel(r"$\hat{w}(r,z)$")
axW.legend(fontsize=8, ncol=2, frameon=True)

# --- H(z) = W/delta
for r0 in r_samples:
    axWt.plot(z_axis, H_test[r0], lw=1.0, label=f"r={r0:.2f}")
axWt.set_xlabel("z")
axWt.set_ylabel(r"$\hat{H}(z)=\hat{w}(r,z)/\delta$")
axWt.legend(fontsize=8, ncol=2, frameon=True)

for ax in [axU, axUt, axV, axVt, axW, axWt]:
    ax.set_title("")


out_png = os.path.join(compare_fig_dir, f"PINN_profiles_similarity_Re{Re_int}_zaxis.png")
out_pdf = os.path.join(compare_fig_dir, f"PINN_profiles_similarity_Re{Re_int}_zaxis.pdf")
fig.savefig(out_png, dpi=200, bbox_inches="tight")
fig.savefig(out_pdf, bbox_inches="tight")
plt.show()

print("[SAVED]", out_png)
print("[SAVED]", out_pdf)
# Out:
# Compiling model...
# 'compile' took 0.000275 s
#
# [LOAD] Re=196 -> pt : SmoothDisk_noise_sweep\Re196_64x4_noise0pct\model_adam-5000.pt
# ...

# %%
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
from scipy.integrate import solve_bvp

import torch
try:
    import torch_directml
    device = torch_directml.device()
except Exception:
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

import deepxde as dde

# ============================================================
# CONFIG
# ============================================================
Re_target = 196                
r_min, r_max = 0.1, 1.0
L_phys = 10.0                  
eta_max_for_plots = 10.0      
Nr_plot = 220
Neta_plot = 260

base_dir = "Outputs_PINN_Smooth"  # root of the model folders
save_dir = os.path.join(base_dir, "VKD_PINN_heatmap_compare")
os.makedirs(save_dir, exist_ok=True)

# ============================================================
# Helpers
# ============================================================
def try_restore_ckpt(model, outdir):
    for fname in sorted(os.listdir(outdir)):
        if fname.endswith(".ckpt"):
            ckpt_path = os.path.join(outdir, fname)
            try:
                model.restore(ckpt_path, verbose=0)
                return True, ("ckpt", ckpt_path)
            except Exception:
                pass
    return False, None

def try_load_pt(net, outdir):
    candidates = [
        "model_adam-10000.pt",
        "model_adam-5000.pt",
        "model_adam-600.pt",
        "model_adam.pt",
        "model_final.pt",
        "model_bfgs-3810.pt",
    ]
    for name in candidates:
        p = os.path.join(outdir, name)
        if os.path.isfile(p):
            state = torch.load(p, map_location=device)
            for cand in [
                state,
                isinstance(state, dict) and state.get("model_state_dict"),
                isinstance(state, dict) and state.get("state_dict"),
                isinstance(state, dict) and state.get("net"),
            ]:
                if isinstance(cand, dict):
                    try:
                        net.load_state_dict(cand, strict=True)
                        return True, ("pt", p)
                    except Exception:
                        pass
    return False, None

def resolve_output_dir(base_dir, Re_int):
    """
    Klasör adın değişkense burada yakala.
    Önce yaygın pattern'ler, sonra glob fallback.
    """
    common = [
        os.path.join(base_dir, f"Re{Re_int}_64x4_noise0pct"),
        os.path.join(base_dir, f"Re{Re_int}_64x4_noise0pct_Nr*_Nz*"),
        os.path.join(base_dir, f"Re{Re_int}_*noise0*pct"),
        os.path.join(base_dir, f"Re{Re_int}_*"),
    ]

    for c in common:
        hits = sorted(glob.glob(c))
        hits = [h for h in hits if os.path.isdir(h)]
        if hits:
            return hits[0]
    raise FileNotFoundError(f"Output dir bulunamadı: base_dir={base_dir}, Re={Re_int}")

def _set_sci_colorbar(cb, powerlimits=(0, 0)):
    """
    Force scientific notation like ×10^{-k} on the colorbar,
    and ensure the offset text is visible (not clipped).
    """
    fmt = ScalarFormatter(useMathText=True)
    fmt.set_scientific(True)
    fmt.set_powerlimits(powerlimits)  

    cb.formatter = fmt
    cb.update_ticks()

    cb.ax.yaxis.set_offset_position("right")
    off = cb.ax.yaxis.get_offset_text()
    off.set_visible(True)
    off.set_fontsize(9)

    # inward shift so it won't be clipped
    off.set_x(1.28)

# ============================================================
# 1) von Kármán similarity BVP
#    y = [F, F', G, G', H]
# ============================================================
def vkd_ode(eta, y):
    f, fp, g, gp, h = y
    return np.vstack([
        fp,
        fp * h + f**2 - g**2,
        gp,
        gp * h + 2.0 * f * g,
        -2.0 * f,
    ])

def vkd_bc(ya, yb):
    return np.array([
        ya[0],        # F(0)=0
        ya[2] - 1.0,  # G(0)=1
        ya[4],        # H(0)=0
        yb[0],        # F(∞)=0
        yb[2],        # G(∞)=0
    ])

def solve_vk(eta_max=10.0):
    eta_init = np.linspace(0.0, eta_max, 250)
    y_guess  = np.zeros((5, eta_init.size))
    y_guess[2, :] = 1.0
    sol = solve_bvp(vkd_ode, vkd_bc, eta_init, y_guess, max_nodes=10000)
    if not sol.success:
        raise RuntimeError("VK BVP yakınsamadı: " + sol.message)
    return sol

vk_sol = solve_vk(eta_max=eta_max_for_plots)

# ============================================================
# 2) Load PINN model for Re_target
#    feature: (r,z) -> (r, eta=z/delta)
#    output:  y -> physical U,V,W,P
# ============================================================
Re_val = float(Re_target)
Re_int = int(Re_val)
delta = Re_val ** (-0.5)              # delta = Re^{-1/2}

layers = [2] + [64] * 4 + [4]
net = dde.nn.FNN(layers, "tanh", "Glorot uniform")

def feature_transform(x, delta=delta):
    r = x[:, 0:1]
    z = x[:, 1:2]
    eta = z / delta
    return torch.cat([r, eta], dim=1)

def output_transform(x, y, delta=delta):
    r = x[:, 0:1]
    U = r * y[:, 0:1]            # physical U
    V = r * y[:, 1:2]            # physical V = r(g-1)
    W = delta * y[:, 2:3]        # physical W = delta*H
    P = (delta**2) * y[:, 3:4]
    return torch.cat([U, V, W, P], dim=1)

net.apply_feature_transform(feature_transform)
net.apply_output_transform(output_transform)
net.to(device)

geom = dde.geometry.Rectangle([r_min, 0.0], [r_max, L_phys])
dummy_data = dde.data.PDE(geom, lambda x, y: [y], [], num_domain=0, num_boundary=0)
model = dde.Model(dummy_data, net)
model.compile("adam", lr=1e-3)

outdir = resolve_output_dir(base_dir, Re_int)
ok, src = try_restore_ckpt(model, outdir)
if not ok:
    ok, src = try_load_pt(net, outdir)
if not ok:
    raise FileNotFoundError(f"Ağırlık bulunamadı: {outdir}")

print(f"[LOAD] Re={Re_int} -> {src[0]} : {src[1]}")

# ============================================================
# 3) Build evaluation grid in (r, eta_plot) but label it as "z"
#    Then convert to physical z for network: z_phys = delta * eta_plot
# ============================================================
r_lin = np.linspace(r_min, r_max, Nr_plot).astype(np.float64)
eta_lin = np.linspace(0.0, eta_max_for_plots, Neta_plot).astype(np.float64)

R, ETA = np.meshgrid(r_lin, eta_lin, indexing="xy")   # shape: (Neta, Nr)
Z_phys = (delta * ETA).astype(np.float64)

X_grid = np.column_stack([R.reshape(-1), Z_phys.reshape(-1)]).astype(np.float32)
Yp = model.predict(X_grid)  # physical [U,V,W,P]

U_pred = Yp[:, 0].reshape(R.shape)
V_pred = Yp[:, 1].reshape(R.shape)
W_pred = Yp[:, 2].reshape(R.shape)   # physical W

# ============================================================
# 4) Reference on same ETA grid: U_ref=r*F(eta), V_ref=r*(G-1), W_ref=delta*H(eta)
# ============================================================
Yvk = vk_sol.sol(eta_lin)   # (5, Neta)
F = Yvk[0, :]               # F(eta)
G = Yvk[2, :]               # G(eta)
H = Yvk[4, :]               # H(eta)

F2 = F.reshape(-1, 1)       # (Neta,1)
G2 = G.reshape(-1, 1)
H2 = H.reshape(-1, 1)

U_ref = (R * F2)                           # (Neta,Nr)
V_ref = (R * (G2 - 1.0))                   # (Neta,Nr)
W_ref = (delta * H2)                       # physical W

# ============================================================
# 5) Absolute pointwise errors
# ============================================================
U_err = np.abs(U_pred - U_ref)
V_err = np.abs(V_pred - V_ref)
W_err = np.abs(W_pred - W_ref)

# ============================================================
# 6) Plot 3x3 heatmaps (NO GRID) + cleaned axis labels
# ============================================================

extent = [r_min, r_max, 0.0, eta_max_for_plots]  # y-axis displayed as "z" in your report

fig, axes = plt.subplots(3, 3, figsize=(10.8, 11.0), dpi=170, constrained_layout=True)

# Column headers (top row) -> keep these
axes[0, 0].set_title("PINN", fontsize=12)
axes[0, 1].set_title("Reference", fontsize=12)
axes[0, 2].set_title(r"$|Pred-Ref|$", fontsize=12)

row_labels = [r"$\hat{u}$", r"$\hat{v}$", r"$\hat{w}$"]

cmap_field = "viridis"
cmap_err = "magma"

def imshow_panel(ax, Z, vmin=None, vmax=None, cmap="viridis",
                 show_xlabel=True, show_ylabel=True, ylabel_text="z"):
    im = ax.imshow(
        Z,
        origin="lower",
        aspect="auto",
        extent=extent,
        cmap=cmap,
        vmin=vmin,
        vmax=vmax,
        interpolation="nearest"
    )

    # Grid OFF
    ax.grid(False)

    # Axis labels: only keep what we want
    if show_xlabel:
        ax.set_xlabel("r")
    else:
        ax.set_xlabel("")

    if show_ylabel:
        ax.set_ylabel(ylabel_text)
    else:
        ax.set_ylabel("")

    return im

# Helper flags:
# - Only left column keeps y-label
# - Only bottom row keeps x-label
def flags(i_row, j_col):
    show_ylabel = (j_col == 0)
    show_xlabel = (i_row == 2)
    return show_xlabel, show_ylabel
# Field ranges: pred ve ref aynı colormap aralığını paylaşsın
U_vmin = float(np.min([U_pred.min(), U_ref.min()]))
U_vmax = float(np.max([U_pred.max(), U_ref.max()]))

V_vmin = float(np.min([V_pred.min(), V_ref.min()]))
V_vmax = float(np.max([V_pred.max(), V_ref.max()]))

W_vmin = float(np.min([W_pred.min(), W_ref.min()]))
W_vmax = float(np.max([W_pred.max(), W_ref.max()]))


# --- Row 1: U ---
sx, sy = flags(0, 0)
im00 = imshow_panel(axes[0, 0], U_pred, vmin=U_vmin, vmax=U_vmax, cmap=cmap_field,
                    show_xlabel=sx, show_ylabel=sy, ylabel_text=row_labels[0])
sx, sy = flags(0, 1)
im01 = imshow_panel(axes[0, 1], U_ref,  vmin=U_vmin, vmax=U_vmax, cmap=cmap_field,
                    show_xlabel=sx, show_ylabel=sy)
sx, sy = flags(0, 2)
im02 = imshow_panel(axes[0, 2], U_err,  vmin=0.0, vmax=U_err.max(), cmap=cmap_err,
                    show_xlabel=sx, show_ylabel=sy)

# --- Row 2: V ---
sx, sy = flags(1, 0)
im10 = imshow_panel(axes[1, 0], V_pred, vmin=V_vmin, vmax=V_vmax, cmap=cmap_field,
                    show_xlabel=sx, show_ylabel=sy, ylabel_text=row_labels[1])
sx, sy = flags(1, 1)
im11 = imshow_panel(axes[1, 1], V_ref,  vmin=V_vmin, vmax=V_vmax, cmap=cmap_field,
                    show_xlabel=sx, show_ylabel=sy)
sx, sy = flags(1, 2)
im12 = imshow_panel(axes[1, 2], V_err,  vmin=0.0, vmax=V_err.max(), cmap=cmap_err,
                    show_xlabel=sx, show_ylabel=sy)

# --- Row 3: W ---
sx, sy = flags(2, 0)
im20 = imshow_panel(axes[2, 0], W_pred, vmin=W_vmin, vmax=W_vmax, cmap=cmap_field,
                    show_xlabel=sx, show_ylabel=sy, ylabel_text=row_labels[2])
sx, sy = flags(2, 1)
im21 = imshow_panel(axes[2, 1], W_ref,  vmin=W_vmin, vmax=W_vmax, cmap=cmap_field,
                    show_xlabel=sx, show_ylabel=sy)
sx, sy = flags(2, 2)
im22 = imshow_panel(axes[2, 2], W_err,  vmin=0.0, vmax=W_err.max(), cmap=cmap_err,
                    show_xlabel=sx, show_ylabel=sy)

# Colorbars (field: normal, error: scientific + visible ×10^k)
def add_cbar(im, ax, sci=False):
    cb = fig.colorbar(im, ax=ax, fraction=0.046, pad=0.02)
    if sci:
        _set_sci_colorbar(cb, powerlimits=(0, 0))
    return cb

# Row 1 cbars
add_cbar(im00, axes[0, 0], sci=False)
add_cbar(im01, axes[0, 1], sci=False)
add_cbar(im02, axes[0, 2], sci=True)

# Row 2 cbars
add_cbar(im10, axes[1, 0], sci=False)
add_cbar(im11, axes[1, 1], sci=False)
add_cbar(im12, axes[1, 2], sci=True)

# Row 3 cbars
add_cbar(im20, axes[2, 0], sci=False)
add_cbar(im21, axes[2, 1], sci=False)
add_cbar(im22, axes[2, 2], sci=True)

# Save (no suptitle)
out_png = os.path.join(save_dir, f"heatmap_compare_Re{Re_int}_eta0_10_as_z.png")
out_pdf = os.path.join(save_dir, f"heatmap_compare_Re{Re_int}_eta0_10_as_z.pdf")

fig.savefig(out_png, dpi=300, bbox_inches="tight")
fig.savefig(out_pdf, bbox_inches="tight")
plt.show()

print(f"[SAVED] {out_png}")
print(f"[SAVED] {out_pdf}")
# Out:
# Compiling model...
# 'compile' took 0.000412 s
#
# [LOAD] Re=196 -> pt : SmoothDisk_noise_sweep\Re196_64x4_noise0pct\model_adam-5000.pt
# ...
